# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
    
#Create a list for holding cities.
cities=[]
#Indentify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    #if the city is unique,then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 749

# %%
import requests

from datetime import datetime

from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            # Append the City information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | shitkino
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | beihai
# Processing Record 5 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 1 | mocuba
# Processing Record 7 of Set 1 | rio gallegos
# Processing Record 8 of Set 1 | acapulco
# Processing Record 9 of Set 1 | araouane
# Processing Record 10 of Set 1 | korla
# Processing Record 11 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | alappuzha
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | ust-uda
# Processing Record 20 of Set 1 | salinopolis
# Processing Record 21 of Set 1 | cuorgne
# Processing Record 22 of Set 1 | pevek
# Processing Record 23 of Set 1 | katsuura
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | isla aguada
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | tuatapere
# Processing Record 28 of Set 1 | chapais
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | hasaki
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | geraldton
# Processing Record 34 of Set 1 | los santos
# Processing Record 35 of Set 1 | ialibu
# Processing Record 36 of Set 1 | constitucion
# Processing Record 37 of Set 1 | severo-yeniseyskiy
# Processing Record 38 of Set 1 | san jose
# Processing Record 39 of Set 1 | upington
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | faya
# Processing Record 43 of Set 1 | algiers
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | tenjo
# Processing Record 47 of Set 1 | jiazi
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | tunceli
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | bud
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | andros town
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | xihe
# Processing Record 7 of Set 2 | stykkisholmur
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | nome
# Processing Record 11 of Set 2 | dunedin
# Processing Record 12 of Set 2 | cherskiy
# Processing Record 13 of Set 2 | yaan
# Processing Record 14 of Set 2 | cap malheureux
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | prince rupert
# Processing Record 17 of Set 2 | saint george
# Processing Record 18 of Set 2 | terrace
# Processing Record 19 of Set 2 | altay
# Processing Record 20 of Set 2 | narsaq
# Processing Record 21 of Set 2 | solano
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | sibolga
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | verkhnevilyuysk
# Processing Record 26 of Set 2 | waipawa
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | srednekolymsk
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | noumea
# Processing Record 33 of Set 2 | malpe
# Processing Record 34 of Set 2 | vila velha
# Processing Record 35 of Set 2 | smithers
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | port lincoln
# Processing Record 38 of Set 2 | walvis bay
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | aksu
# Processing Record 43 of Set 2 | burnie
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | itaituba
# Processing Record 46 of Set 2 | lompoc
# Processing Record 47 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | lashio
# Processing Record 50 of Set 2 | westport
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 3 | acajutla
# Processing Record 4 of Set 3 | sur
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | yar-sale
# Processing Record 7 of Set 3 | prachuap khiri khan
# Processing Record 8 of Set 3 | victoria
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | esperance
# Processing Record 11 of Set 3 | zhanaozen
# Processing Record 12 of Set 3 | cozumel
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | ust-kulom
# Processing Record 15 of Set 3 | kikwit
# Processing Record 16 of Set 3 | zaragoza
# Processing Record 17 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | skiros
# City not found. Skipping...
# Processing Record 20 of Set 3 | northam
# Processing Record 21 of Set 3 | cabo san lucas
# Processing Record 22 of Set 3 | sola
# Processing Record 23 of Set 3 | porosozero
# Processing Record 24 of Set 3 | maniitsoq
# Processing Record 25 of Set 3 | mana
# Processing Record 26 of Set 3 | maksatikha
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | mehar
# Processing Record 29 of Set 3 | margate
# Processing Record 30 of Set 3 | saskylakh
# Processing Record 31 of Set 3 | naze
# Processing Record 32 of Set 3 | chuy
# Processing Record 33 of Set 3 | soyo
# Processing Record 34 of Set 3 | jining
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | lac du bonnet
# Processing Record 38 of Set 3 | te anau
# Processing Record 39 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 3 | leh
# Processing Record 41 of Set 3 | ardakan
# Processing Record 42 of Set 3 | biak
# Processing Record 43 of Set 3 | kiama
# Processing Record 44 of Set 3 | tura
# Processing Record 45 of Set 3 | tiarei
# Processing Record 46 of Set 3 | semnan
# Processing Record 47 of Set 3 | richards bay
# Processing Record 48 of Set 3 | sao gabriel da cachoeira
# Processing Record 49 of Set 3 | aqtobe
# Processing Record 50 of Set 3 | zhigansk
# Processing Record 1 of Set 4 | faxinal
# Processing Record 2 of Set 4 | kloulklubed
# Processing Record 3 of Set 4 | chumphon
# Processing Record 4 of Set 4 | hella
# Processing Record 5 of Set 4 | epe
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | gamba
# Processing Record 8 of Set 4 | arman
# Processing Record 9 of Set 4 | saint-philippe
# Processing Record 10 of Set 4 | sept-iles
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | necochea
# Processing Record 13 of Set 4 | mandalgovi
# Processing Record 14 of Set 4 | mount isa
# Processing Record 15 of Set 4 | lorengau
# Processing Record 16 of Set 4 | mahina
# Processing Record 17 of Set 4 | maisach
# Processing Record 18 of Set 4 | leningradskiy
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | abha
# Processing Record 21 of Set 4 | goderich
# Processing Record 22 of Set 4 | zhongshu
# Processing Record 23 of Set 4 | banda aceh
# Processing Record 24 of Set 4 | mangla
# Processing Record 25 of Set 4 | torbay
# Processing Record 26 of Set 4 | tabas
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | albany
# Processing Record 29 of Set 4 | souillac
# Processing Record 30 of Set 4 | lalawigan
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | talnakh
# Processing Record 33 of Set 4 | salalah
# Processing Record 34 of Set 4 | faanui
# Processing Record 35 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 4 | padang
# Processing Record 37 of Set 4 | nuevo progreso
# Processing Record 38 of Set 4 | sainte-rose
# Processing Record 39 of Set 4 | okakarara
# Processing Record 40 of Set 4 | ilulissat
# Processing Record 41 of Set 4 | tricase
# Processing Record 42 of Set 4 | atuona
# Processing Record 43 of Set 4 | limon
# Processing Record 44 of Set 4 | laguna
# Processing Record 45 of Set 4 | tabou
# Processing Record 46 of Set 4 | dingle
# Processing Record 47 of Set 4 | katangli
# Processing Record 48 of Set 4 | sao filipe
# Processing Record 49 of Set 4 | ust-omchug
# Processing Record 50 of Set 4 | prince albert
# Processing Record 1 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 5 | shar
# Processing Record 3 of Set 5 | portland
# Processing Record 4 of Set 5 | boa vista
# Processing Record 5 of Set 5 | codrington
# Processing Record 6 of Set 5 | linda
# Processing Record 7 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 5 | jujuy
# City not found. Skipping...
# Processing Record 9 of Set 5 | nizwa
# Processing Record 10 of Set 5 | jasper
# Processing Record 11 of Set 5 | hoquiam
# Processing Record 12 of Set 5 | chegdomyn
# Processing Record 13 of Set 5 | dagupan
# Processing Record 14 of Set 5 | port elizabeth
# Processing Record 15 of Set 5 | ales
# Processing Record 16 of Set 5 | matamoros
# Processing Record 17 of Set 5 | avera
# Processing Record 18 of Set 5 | tuktoyaktuk
# Processing Record 19 of Set 5 | zhucheng
# Processing Record 20 of Set 5 | rocha
# Processing Record 21 of Set 5 | port hawkesbury
# Processing Record 22 of Set 5 | bardiyah
# Processing Record 23 of Set 5 | camacha
# Processing Record 24 of Set 5 | rawson
# Processing Record 25 of Set 5 | cayenne
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | ust-maya
# Processing Record 28 of Set 5 | provideniya
# Processing Record 29 of Set 5 | kjollefjord
# Processing Record 30 of Set 5 | isangel
# Processing Record 31 of Set 5 | odweyne
# Processing Record 32 of Set 5 | belz
# Processing Record 33 of Set 5 | pucallpa
# Processing Record 34 of Set 5 | kozhva
# Processing Record 35 of Set 5 | saint-augustin
# Processing Record 36 of Set 5 | norman wells
# Processing Record 37 of Set 5 | college
# Processing Record 38 of Set 5 | vila franca do campo
# Processing Record 39 of Set 5 | rio grande
# Processing Record 40 of Set 5 | tessalit
# Processing Record 41 of Set 5 | escarcega
# Processing Record 42 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 5 | sobolevo
# Processing Record 44 of Set 5 | guerrero negro
# Processing Record 45 of Set 5 | mitsamiouli
# Processing Record 46 of Set 5 | jinchang
# Processing Record 47 of Set 5 | kalmunai
# Processing Record 48 of Set 5 | kungurtug
# Processing Record 49 of Set 5 | ebebiyin
# Processing Record 50 of Set 5 | inta
# Processing Record 1 of Set 6 | kahului
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | teguldet
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | asau
# Processing Record 6 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 7 of Set 6 | mar del plata
# Processing Record 8 of Set 6 | pipri
# Processing Record 9 of Set 6 | hamilton
# Processing Record 10 of Set 6 | khatanga
# Processing Record 11 of Set 6 | port augusta
# Processing Record 12 of Set 6 | lufkin
# Processing Record 13 of Set 6 | kavieng
# Processing Record 14 of Set 6 | sangar
# Processing Record 15 of Set 6 | sitka
# Processing Record 16 of Set 6 | port hardy
# Processing Record 17 of Set 6 | georgetown
# Processing Record 18 of Set 6 | longyearbyen
# Processing Record 19 of Set 6 | shakiso
# Processing Record 20 of Set 6 | aberdeen
# Processing Record 21 of Set 6 | surt
# Processing Record 22 of Set 6 | airai
# Processing Record 23 of Set 6 | badhni kalan
# Processing Record 24 of Set 6 | calderitas
# Processing Record 25 of Set 6 | kaitangata
# Processing Record 26 of Set 6 | san andres
# Processing Record 27 of Set 6 | ahipara
# Processing Record 28 of Set 6 | pokrovskoye
# Processing Record 29 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | talca
# Processing Record 31 of Set 6 | bathsheba
# Processing Record 32 of Set 6 | calamar
# Processing Record 33 of Set 6 | coquimbo
# Processing Record 34 of Set 6 | launceston
# Processing Record 35 of Set 6 | cidreira
# Processing Record 36 of Set 6 | santa maria
# Processing Record 37 of Set 6 | forestville
# Processing Record 38 of Set 6 | bari
# Processing Record 39 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 6 | praya
# Processing Record 41 of Set 6 | haines junction
# Processing Record 42 of Set 6 | roma
# Processing Record 43 of Set 6 | nikolskoye
# Processing Record 44 of Set 6 | maceio
# Processing Record 45 of Set 6 | nemuro
# Processing Record 46 of Set 6 | nova olimpia
# Processing Record 47 of Set 6 | sechura
# Processing Record 48 of Set 6 | puerto leguizamo
# Processing Record 49 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 6 | sydney
# Processing Record 1 of Set 7 | zhuanghe
# Processing Record 2 of Set 7 | port blair
# Processing Record 3 of Set 7 | ravenna
# Processing Record 4 of Set 7 | christchurch
# Processing Record 5 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | lokosovo
# Processing Record 7 of Set 7 | pisco
# Processing Record 8 of Set 7 | ixtapa
# Processing Record 9 of Set 7 | abilene
# Processing Record 10 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 7 | sarangani
# Processing Record 12 of Set 7 | stornoway
# Processing Record 13 of Set 7 | pocking
# Processing Record 14 of Set 7 | oxford
# Processing Record 15 of Set 7 | saldanha
# Processing Record 16 of Set 7 | katiola
# Processing Record 17 of Set 7 | akyab
# Processing Record 18 of Set 7 | coro
# Processing Record 19 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 20 of Set 7 | puerto madryn
# Processing Record 21 of Set 7 | comodoro rivadavia
# Processing Record 22 of Set 7 | zhumadian
# Processing Record 23 of Set 7 | jumla
# Processing Record 24 of Set 7 | koungou
# Processing Record 25 of Set 7 | port-cartier
# Processing Record 26 of Set 7 | lagoa
# Processing Record 27 of Set 7 | swan river
# Processing Record 28 of Set 7 | panaba
# Processing Record 29 of Set 7 | roebourne
# Processing Record 30 of Set 7 | nyurba
# Processing Record 31 of Set 7 | hirara
# Processing Record 32 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 7 | bandarbeyla
# Processing Record 34 of Set 7 | razole
# Processing Record 35 of Set 7 | bafoulabe
# Processing Record 36 of Set 7 | pyshchug
# Processing Record 37 of Set 7 | anloga
# Processing Record 38 of Set 7 | whitehorse
# Processing Record 39 of Set 7 | neiafu
# Processing Record 40 of Set 7 | caldwell
# Processing Record 41 of Set 7 | talovaya
# Processing Record 42 of Set 7 | fecamp
# Processing Record 43 of Set 7 | shelburne
# Processing Record 44 of Set 7 | sorland
# Processing Record 45 of Set 7 | san cristobal
# Processing Record 46 of Set 7 | sao joao da barra
# Processing Record 47 of Set 7 | flinders
# Processing Record 48 of Set 7 | gazanjyk
# Processing Record 49 of Set 7 | hire
# City not found. Skipping...
# Processing Record 50 of Set 7 | elizabeth city
# Processing Record 1 of Set 8 | atambua
# Processing Record 2 of Set 8 | lucapa
# Processing Record 3 of Set 8 | hobyo
# Processing Record 4 of Set 8 | klaksvik
# Processing Record 5 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 8 | pangnirtung
# Processing Record 7 of Set 8 | fairbanks
# Processing Record 8 of Set 8 | juxian
# City not found. Skipping...
# Processing Record 9 of Set 8 | koster
# Processing Record 10 of Set 8 | maunabo
# Processing Record 11 of Set 8 | huilong
# Processing Record 12 of Set 8 | trairi
# Processing Record 13 of Set 8 | manokwari
# Processing Record 14 of Set 8 | ankang
# Processing Record 15 of Set 8 | waingapu
# Processing Record 16 of Set 8 | bubaque
# Processing Record 17 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 8 | sakaiminato
# Processing Record 19 of Set 8 | manaus
# Processing Record 20 of Set 8 | urumqi
# Processing Record 21 of Set 8 | conde
# Processing Record 22 of Set 8 | san quintin
# Processing Record 23 of Set 8 | russell
# Processing Record 24 of Set 8 | kununurra
# Processing Record 25 of Set 8 | itamarandiba
# Processing Record 26 of Set 8 | dali
# Processing Record 27 of Set 8 | galle
# Processing Record 28 of Set 8 | broome
# Processing Record 29 of Set 8 | paucartambo
# City not found. Skipping...
# Processing Record 30 of Set 8 | emba
# Processing Record 31 of Set 8 | avarua
# Processing Record 32 of Set 8 | den helder
# Processing Record 33 of Set 8 | edirne
# Processing Record 34 of Set 8 | catamarca
# Processing Record 35 of Set 8 | salym
# Processing Record 36 of Set 8 | burica
# City not found. Skipping...
# Processing Record 37 of Set 8 | bara
# Processing Record 38 of Set 8 | san patricio
# Processing Record 39 of Set 8 | bartica
# Processing Record 40 of Set 8 | brae
# Processing Record 41 of Set 8 | ratnagiri
# Processing Record 42 of Set 8 | asfi
# Processing Record 43 of Set 8 | nuuk
# Processing Record 44 of Set 8 | ocosingo
# Processing Record 45 of Set 8 | kralendijk
# Processing Record 46 of Set 8 | lapeer
# Processing Record 47 of Set 8 | bonavista
# Processing Record 48 of Set 8 | sao bento do sul
# Processing Record 49 of Set 8 | liminangcong
# City not found. Skipping...
# Processing Record 50 of Set 8 | semey
# Processing Record 1 of Set 9 | nantucket
# Processing Record 2 of Set 9 | tiksi
# Processing Record 3 of Set 9 | chieri
# Processing Record 4 of Set 9 | vyazemskiy
# Processing Record 5 of Set 9 | le port
# Processing Record 6 of Set 9 | flin flon
# Processing Record 7 of Set 9 | baykit
# Processing Record 8 of Set 9 | anaconda
# Processing Record 9 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 10 of Set 9 | husavik
# Processing Record 11 of Set 9 | papayal
# Processing Record 12 of Set 9 | hope
# Processing Record 13 of Set 9 | agadez
# Processing Record 14 of Set 9 | tautira
# Processing Record 15 of Set 9 | billings
# Processing Record 16 of Set 9 | peniche
# Processing Record 17 of Set 9 | tshikapa
# Processing Record 18 of Set 9 | vagamo
# Processing Record 19 of Set 9 | iskateley
# Processing Record 20 of Set 9 | aykhal
# Processing Record 21 of Set 9 | makat
# Processing Record 22 of Set 9 | mamlyutka
# Processing Record 23 of Set 9 | belmonte
# Processing Record 24 of Set 9 | vestmannaeyjar
# Processing Record 25 of Set 9 | marica
# Processing Record 26 of Set 9 | saint anthony
# Processing Record 27 of Set 9 | bagdarin
# Processing Record 28 of Set 9 | ampanihy
# Processing Record 29 of Set 9 | tahe
# Processing Record 30 of Set 9 | mayo
# Processing Record 31 of Set 9 | la ronge
# Processing Record 32 of Set 9 | nyuksenitsa
# Processing Record 33 of Set 9 | manica
# Processing Record 34 of Set 9 | zambezi
# Processing Record 35 of Set 9 | chincha alta
# Processing Record 36 of Set 9 | santa barbara
# Processing Record 37 of Set 9 | aklavik
# Processing Record 38 of Set 9 | lavrentiya
# Processing Record 39 of Set 9 | new waterford
# Processing Record 40 of Set 9 | alyangula
# Processing Record 41 of Set 9 | los llanos de aridane
# Processing Record 42 of Set 9 | meulaboh
# Processing Record 43 of Set 9 | harbour breton
# Processing Record 44 of Set 9 | bontang
# Processing Record 45 of Set 9 | vitim
# Processing Record 46 of Set 9 | norrtalje
# Processing Record 47 of Set 9 | labrea
# Processing Record 48 of Set 9 | ilovlya
# Processing Record 49 of Set 9 | la palma
# Processing Record 50 of Set 9 | marsa matruh
# Processing Record 1 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 2 of Set 10 | ca mau
# Processing Record 3 of Set 10 | lake cowichan
# Processing Record 4 of Set 10 | puerto del rosario
# Processing Record 5 of Set 10 | madimba
# Processing Record 6 of Set 10 | arlit
# Processing Record 7 of Set 10 | romny
# Processing Record 8 of Set 10 | jiujiang
# Processing Record 9 of Set 10 | weinan
# Processing Record 10 of Set 10 | lisbon
# Processing Record 11 of Set 10 | belyy yar
# Processing Record 12 of Set 10 | mackay
# Processing Record 13 of Set 10 | barreirinha
# Processing Record 14 of Set 10 | atar
# Processing Record 15 of Set 10 | deputatskiy
# Processing Record 16 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 17 of Set 10 | cururupu
# Processing Record 18 of Set 10 | canavieiras
# Processing Record 19 of Set 10 | ulaangom
# Processing Record 20 of Set 10 | quelimane
# Processing Record 21 of Set 10 | broken hill
# Processing Record 22 of Set 10 | gossas
# Processing Record 23 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 24 of Set 10 | havre-saint-pierre
# Processing Record 25 of Set 10 | vestmanna
# Processing Record 26 of Set 10 | nouadhibou
# Processing Record 27 of Set 10 | mancio lima
# Processing Record 28 of Set 10 | lata
# Processing Record 29 of Set 10 | jemnice
# Processing Record 30 of Set 10 | shikhazany
# Processing Record 31 of Set 10 | anjiang
# Processing Record 32 of Set 10 | paamiut
# Processing Record 33 of Set 10 | qasigiannguit
# Processing Record 34 of Set 10 | azovo
# Processing Record 35 of Set 10 | hokitika
# Processing Record 36 of Set 10 | pierre
# Processing Record 37 of Set 10 | santa cruz
# Processing Record 38 of Set 10 | alice springs
# Processing Record 39 of Set 10 | nago
# Processing Record 40 of Set 10 | kaduqli
# Processing Record 41 of Set 10 | veraval
# Processing Record 42 of Set 10 | katherine
# Processing Record 43 of Set 10 | keti bandar
# Processing Record 44 of Set 10 | palasa
# Processing Record 45 of Set 10 | timmins
# Processing Record 46 of Set 10 | outjo
# Processing Record 47 of Set 10 | katha
# City not found. Skipping...
# Processing Record 48 of Set 10 | hay river
# Processing Record 49 of Set 10 | bata
# Processing Record 50 of Set 10 | nyimba
# Processing Record 1 of Set 11 | olafsvik
# Processing Record 2 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 3 of Set 11 | cockburn town
# Processing Record 4 of Set 11 | dubbo
# Processing Record 5 of Set 11 | ouesso
# Processing Record 6 of Set 11 | shimoda
# Processing Record 7 of Set 11 | shieli
# Processing Record 8 of Set 11 | mugango
# Processing Record 9 of Set 11 | verkhoyansk
# Processing Record 10 of Set 11 | xiazhen
# Processing Record 11 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 11 | samarai
# Processing Record 13 of Set 11 | hofn
# Processing Record 14 of Set 11 | dolores
# Processing Record 15 of Set 11 | new ulm
# Processing Record 16 of Set 11 | wajima
# Processing Record 17 of Set 11 | fukue
# Processing Record 18 of Set 11 | okhotsk
# Processing Record 19 of Set 11 | takoradi
# Processing Record 20 of Set 11 | stargard szczecinski
# Processing Record 21 of Set 11 | berdigestyakh
# Processing Record 22 of Set 11 | suzu
# City not found. Skipping...
# Processing Record 23 of Set 11 | santa teresa
# Processing Record 24 of Set 11 | itarema
# Processing Record 25 of Set 11 | nieuw amsterdam
# Processing Record 26 of Set 11 | tezu
# Processing Record 27 of Set 11 | finschhafen
# Processing Record 28 of Set 11 | alofi
# Processing Record 29 of Set 11 | coihaique
# Processing Record 30 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 11 | wiang sa
# Processing Record 32 of Set 11 | nanortalik
# Processing Record 33 of Set 11 | erzin
# Processing Record 34 of Set 11 | shenkursk
# Processing Record 35 of Set 11 | poronaysk
# Processing Record 36 of Set 11 | devonport
# Processing Record 37 of Set 11 | dekar
# Processing Record 38 of Set 11 | carballo
# Processing Record 39 of Set 11 | aden
# Processing Record 40 of Set 11 | poli
# Processing Record 41 of Set 11 | petatlan
# Processing Record 42 of Set 11 | kumluca
# Processing Record 43 of Set 11 | roald
# Processing Record 44 of Set 11 | manyana
# Processing Record 45 of Set 11 | half moon bay
# Processing Record 46 of Set 11 | octeville
# Processing Record 47 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 11 | lasa
# Processing Record 49 of Set 11 | carutapera
# Processing Record 50 of Set 11 | puerto escondido
# Processing Record 1 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 12 | komsomolskiy
# Processing Record 3 of Set 12 | omboue
# Processing Record 4 of Set 12 | bet shemesh
# Processing Record 5 of Set 12 | hambantota
# Processing Record 6 of Set 12 | zelenoborsk
# Processing Record 7 of Set 12 | tanout
# Processing Record 8 of Set 12 | medicine hat
# Processing Record 9 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 10 of Set 12 | north bend
# Processing Record 11 of Set 12 | taos
# Processing Record 12 of Set 12 | noshiro
# Processing Record 13 of Set 12 | cairns
# Processing Record 14 of Set 12 | vardo
# Processing Record 15 of Set 12 | moron
# Processing Record 16 of Set 12 | san rafael
# Processing Record 17 of Set 12 | nizhniy lomov
# Processing Record 18 of Set 12 | miri
# Processing Record 19 of Set 12 | eyl
# Processing Record 20 of Set 12 | riyadh
# Processing Record 21 of Set 12 | manta
# Processing Record 22 of Set 12 | apt
# Processing Record 23 of Set 12 | sinfra
# Processing Record 24 of Set 12 | ornskoldsvik
# Processing Record 25 of Set 12 | sa kaeo
# Processing Record 26 of Set 12 | vostok
# Processing Record 27 of Set 12 | quepos
# Processing Record 28 of Set 12 | kidal
# Processing Record 29 of Set 12 | cabedelo
# Processing Record 30 of Set 12 | inzer
# Processing Record 31 of Set 12 | montepuez
# Processing Record 32 of Set 12 | ojinaga
# Processing Record 33 of Set 12 | labuhan
# Processing Record 34 of Set 12 | marzuq
# Processing Record 35 of Set 12 | zyryanovsk
# Processing Record 36 of Set 12 | yulara
# Processing Record 37 of Set 12 | huarmey
# Processing Record 38 of Set 12 | quatre cocos
# Processing Record 39 of Set 12 | chiredzi
# Processing Record 40 of Set 12 | lochmaben
# Processing Record 41 of Set 12 | yeppoon
# Processing Record 42 of Set 12 | nanakuli
# Processing Record 43 of Set 12 | baie-comeau
# Processing Record 44 of Set 12 | chardara
# Processing Record 45 of Set 12 | tagbac
# Processing Record 46 of Set 12 | caborca
# Processing Record 47 of Set 12 | bac lieu
# Processing Record 48 of Set 12 | strezhevoy
# Processing Record 49 of Set 12 | kolokani
# Processing Record 50 of Set 12 | la asuncion
# Processing Record 1 of Set 13 | beira
# Processing Record 2 of Set 13 | kashan
# Processing Record 3 of Set 13 | novyy urengoy
# Processing Record 4 of Set 13 | basco
# Processing Record 5 of Set 13 | tahoua
# Processing Record 6 of Set 13 | korsakovo
# Processing Record 7 of Set 13 | guia lopes da laguna
# Processing Record 8 of Set 13 | goundam
# Processing Record 9 of Set 13 | acarau
# Processing Record 10 of Set 13 | kuzhithurai
# Processing Record 11 of Set 13 | oranjemund
# Processing Record 12 of Set 13 | paragominas
# Processing Record 13 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 13 | tocopilla
# Processing Record 15 of Set 13 | huesca
# Processing Record 16 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 13 | valdivia
# Processing Record 18 of Set 13 | paka
# Processing Record 19 of Set 13 | xichang
# Processing Record 20 of Set 13 | panguna
# Processing Record 21 of Set 13 | caledon
# Processing Record 22 of Set 13 | fenoarivo
# Processing Record 23 of Set 13 | sale
# Processing Record 24 of Set 13 | xuddur
# Processing Record 25 of Set 13 | plavinas
# Processing Record 26 of Set 13 | severnyy
# Processing Record 27 of Set 13 | virginia beach
# Processing Record 28 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 13 | kirovskiy
# Processing Record 30 of Set 13 | mabaruma
# Processing Record 31 of Set 13 | sokoni
# Processing Record 32 of Set 13 | castres
# Processing Record 33 of Set 13 | tarakan
# Processing Record 34 of Set 13 | accrington
# Processing Record 35 of Set 13 | ambanja
# Processing Record 36 of Set 13 | beidao
# Processing Record 37 of Set 13 | kudahuvadhoo
# Processing Record 38 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 39 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 13 | tilichiki
# Processing Record 41 of Set 13 | mehamn
# Processing Record 42 of Set 13 | anadyr
# Processing Record 43 of Set 13 | viedma
# Processing Record 44 of Set 13 | the valley
# Processing Record 45 of Set 13 | alekseyevsk
# Processing Record 46 of Set 13 | pontianak
# Processing Record 47 of Set 13 | zaysan
# Processing Record 48 of Set 13 | pangai
# Processing Record 49 of Set 13 | luwuk
# Processing Record 50 of Set 13 | myrtle beach
# Processing Record 1 of Set 14 | dana point
# Processing Record 2 of Set 14 | bahia blanca
# Processing Record 3 of Set 14 | oksfjord
# Processing Record 4 of Set 14 | dosso
# Processing Record 5 of Set 14 | abu dhabi
# Processing Record 6 of Set 14 | sinjai
# Processing Record 7 of Set 14 | charters towers
# Processing Record 8 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 9 of Set 14 | hearst
# Processing Record 10 of Set 14 | gat
# Processing Record 11 of Set 14 | ust-koksa
# Processing Record 12 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 14 | namatanai
# Processing Record 14 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 14 | banjar
# Processing Record 17 of Set 14 | churumuco
# City not found. Skipping...
# Processing Record 18 of Set 14 | kyrylivka
# Processing Record 19 of Set 14 | majene
# Processing Record 20 of Set 14 | shahpur
# Processing Record 21 of Set 14 | harper
# Processing Record 22 of Set 14 | elmira
# Processing Record 23 of Set 14 | polyarnyy
# Processing Record 24 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 14 | ereymentau
# Processing Record 26 of Set 14 | la romana
# Processing Record 27 of Set 14 | gubkinskiy
# Processing Record 28 of Set 14 | pasni
# Processing Record 29 of Set 14 | san pedro
# Processing Record 30 of Set 14 | wajir
# Processing Record 31 of Set 14 | hit
# Processing Record 32 of Set 14 | mollendo
# Processing Record 33 of Set 14 | susuman
# Processing Record 34 of Set 14 | maryborough
# Processing Record 35 of Set 14 | khorramshahr
# Processing Record 36 of Set 14 | manacapuru
# Processing Record 37 of Set 14 | itanagar
# Processing Record 38 of Set 14 | miramar
# Processing Record 39 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 40 of Set 14 | pontal do parana
# Processing Record 41 of Set 14 | ola
# Processing Record 42 of Set 14 | chaoyang
# Processing Record 43 of Set 14 | mizdah
# Processing Record 44 of Set 14 | yemtsa
# Processing Record 45 of Set 14 | kalanguy
# Processing Record 46 of Set 14 | mokrous
# Processing Record 47 of Set 14 | nacala
# Processing Record 48 of Set 14 | santa lucia
# Processing Record 49 of Set 14 | muskegon
# Processing Record 50 of Set 14 | sioux lookout
# Processing Record 1 of Set 15 | beruwala
# Processing Record 2 of Set 15 | harnosand
# Processing Record 3 of Set 15 | nabire
# Processing Record 4 of Set 15 | manzhouli
# Processing Record 5 of Set 15 | yanchukan
# City not found. Skipping...
# Processing Record 6 of Set 15 | grootfontein
# Processing Record 7 of Set 15 | nador
# Processing Record 8 of Set 15 | batagay-alyta
# Processing Record 9 of Set 15 | vao
# Processing Record 10 of Set 15 | mount gambier
# Processing Record 11 of Set 15 | sao jose da coroa grande
# Processing Record 12 of Set 15 | shestakovo
# Processing Record 13 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 14 of Set 15 | chabahar
# Processing Record 15 of Set 15 | ostrovnoy
# Processing Record 16 of Set 15 | bolobo
# Processing Record 17 of Set 15 | iroquois falls
# Processing Record 18 of Set 15 | san luis
# Processing Record 19 of Set 15 | hongan
# City not found. Skipping...
# Processing Record 20 of Set 15 | nizhnevartovsk
# Processing Record 21 of Set 15 | lagos
# Processing Record 22 of Set 15 | witrivier
# City not found. Skipping...
# Processing Record 23 of Set 15 | gornopravdinsk
# Processing Record 24 of Set 15 | aviles
# Processing Record 25 of Set 15 | magadan
# Processing Record 26 of Set 15 | balikpapan
# Processing Record 27 of Set 15 | ponte de sor
# Processing Record 28 of Set 15 | banikoara
# Processing Record 29 of Set 15 | honiara
# Processing Record 30 of Set 15 | presidencia roque saenz pena
# Processing Record 31 of Set 15 | yabrud
# Processing Record 32 of Set 15 | traunstein
# Processing Record 33 of Set 15 | gambo
# Processing Record 34 of Set 15 | monrovia
# Processing Record 35 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 15 | nishihara
# Processing Record 37 of Set 15 | aurillac
# Processing Record 38 of Set 15 | vahan
# Processing Record 39 of Set 15 | vesoul
# Processing Record 40 of Set 15 | slave lake
# Processing Record 41 of Set 15 | port-gentil
# Processing Record 42 of Set 15 | umarkhed
# Processing Record 43 of Set 15 | tommot
# Processing Record 44 of Set 15 | taldan
# Processing Record 45 of Set 15 | nouakchott
# Processing Record 46 of Set 15 | taicheng
# Processing Record 47 of Set 15 | lyngseidet
# Processing Record 48 of Set 15 | egvekinot
# Processing Record 49 of Set 15 | mirabad
# -----------------------------
# Data Retrieval Complete

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.head(2)
# Out:
#        City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0  Shitkino  56.3703   98.3543      3.81       broken clouds        93
# 1    Hobart -42.8794  147.3294     62.60     overcast clouds        55
#
#    Cloudiness  Wind Speed Country
# 0          68        5.55      RU
# 1          90       13.80      AU

# %%
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity",
                    "Cloudiness", "Wind Speed",
                    "Current Description"]
# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(2)
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Shitkino      RU  56.3703   98.3543      3.81        93          68
# 1    Hobart      AU -42.8794  147.3294     62.60        55          90
#
#    Wind Speed Current Description
# 0        5.55       broken clouds
# 1       13.80     overcast clouds

# %%
# Create the output File (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
